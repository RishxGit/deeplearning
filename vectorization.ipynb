# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a = np.random.rand(1000000)
b = np.random.rand(1000000)

# %%
c = np.dot(a,b)

# %%
print(c)
# Out:
# 250007.6275158108
