# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
a = np.random.rand(1000000)
b = np.random.rand(1000000)

# %%
c = np.dot(a,b)

# %%
print(c)
# Out:
# 250007.6275158108

# %%
A = np.array([[56.0, 0.0, 4.4, 68.0],
              [1.2, 104.0, 52.0, 8.0],
              [1.8, 135.0, 99.0, 0.9]])

# %%
print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal = A.sum(axis=0)
print(cal)
# Out:
# [ 59.  239.  155.4  76.9]

# %%
percentage = 100*A/cal.reshape(1,4)
print(percentage)
# Out:
# [[94.91525424  0.          2.83140283 88.42652796]
#  [ 2.03389831 43.51464435 33.46203346 10.40312094]
#  [ 3.05084746 56.48535565 63.70656371  1.17035111]]

# %%
a = np.random.randn(5) #DONT USE RANK 1 ARRAY
print(a)
# Out:
# [-0.74493814 -0.17062676 -0.27458511  0.31739262 -0.78513836]

# %%
print(a.shape)
# Out:
# (5,)

# %%
#TRANSPOSE
print(a.T)
# Out:
# [ 0.41340655 -0.98031264  0.13611662  1.25845665  1.13032886]

# %%
print(np.dot(a,a.T))
# Out:
# 4.011802078367916

# %%
a = np.random.randn(5,1)
print(a)
# Out:
# [[ 0.61278164]
#  [-0.06782667]
#  [ 0.51642467]
#  [-2.08975916]
#  [ 0.55805687]]

# %%
print(a.T)
#TWO SQUARE BRACKETS
# Out:
# [[ 0.61278164 -0.06782667  0.51642467 -2.08975916  0.55805687]]

# %%
print(np.dot(a,a.T))
# Out:
# [[ 0.37550134 -0.04156294  0.31645556 -1.28056605  0.34196701]
#  [-0.04156294  0.00460046 -0.03502736  0.1417414  -0.03785114]
#  [ 0.31645556 -0.03502736  0.26669444 -1.07920319  0.28819434]
#  [-1.28056605  0.1417414  -1.07920319  4.36709333 -1.16620446]
#  [ 0.34196701 -0.03785114  0.28819434 -1.16620446  0.31142747]]
